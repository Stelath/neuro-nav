# %%
import time
import math
import sdl2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from brainflow.board_shim import BoardShim, BrainFlowInputParams, LogLevels, BoardIds
from brainflow.data_filter import DataFilter, AggOperations, FilterTypes, WindowOperations, NoiseTypes

from stable_baselines3 import PPO
from eeg_ccn_extractor import EEGCNNExtractor
from kinetic_gym import KineticEnv

# %%
policy_kwargs = dict(
    features_extractor_class=EEGCNNExtractor,
    features_extractor_kwargs=dict(features_dim=256),
)

env = KineticEnv()
model = PPO('CnnPolicy', env, policy_kwargs=policy_kwargs, verbose=1)
# Out:
# [2023-01-23 23:32:59.151] [board_logger] [info] incoming json: {
#     "board_id": 23,
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "C0:EE:40:84:DD:56",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "58a99b0107e64cd40ea5e6607882cbe2",
#     "serial_port": "",
#     "timeout": 5
# }
# [2023-01-23 23:32:59.151] [board_logger] [trace] Board object created 23
# [2023-01-23 23:32:59.151] [board_logger] [debug] Use IP port 9000
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
def callback(*args):
    env.render()

model.learn(total_timesteps=100, callback=callback, tb_log_name="./ppo_kinetic")
# Out:
# /home/stelath/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:105: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.buf_obs[key][env_idx] = obs
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.6
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.64
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.16
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 def callback(*args):
#       2     env.render()
# ----> 4 model.learn(total_timesteps=100, callback=callback, tb_log_name="./ppo_kinetic")
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:307, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 def learn(
#     298     self: SelfPPO,
#     299     total_timesteps: int,
#    (...)
#     304     progress_bar: bool = False,
#     305 ) -> SelfPPO:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:248, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 callback.on_training_start(locals(), globals())
#     246 while self.num_timesteps < total_timesteps:
# --> 248     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     250     if continue_training is False:
#     251         break
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:175, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     172 if isinstance(self.action_space, spaces.Box):
#     173     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 175 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     177 self.num_timesteps += env.num_envs
#     179 # Give access to local variables
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/miniconda3/envs/neuronav/lib/python3.8/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File ~/GitHub/neuro-nav/kinetic_gym.py:90, in KineticEnv.step(self, action)
#      87 def step(self, action):
#      88     x, y = self.get_direction()
# ---> 90     time.sleep(0.1)
#      92     # WARNING: A bit offset because of drift, should be 0.2 and -0.2 for the deadzone
#      93     self.real_direction = 2 if x / 32768 > 0.3 else 0 if x / 32768 < -0.1 else 1
#
# KeyboardInterrupt:

# %%
model.save("ppo_kinetic.pth")
