# %%
import time
import math
import sdl2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from brainflow.board_shim import BoardShim, BrainFlowInputParams, LogLevels, BoardIds
from brainflow.data_filter import DataFilter, AggOperations, FilterTypes, WindowOperations, NoiseTypes

from stable_baselines3 import PPO
from eeg_ccn_extractor import EEGCNNExtractor
from kinetic_gym import KineticEnv

# %%
policy_kwargs = dict(
    features_extractor_class=EEGCNNExtractor,
    features_extractor_kwargs=dict(features_dim=256),
)

env = KineticEnv()
model = PPO('CnnPolicy', env, policy_kwargs=policy_kwargs, verbose=1)
# Out:
# [2023-02-01 23:26:01.056] [board_logger] [info] incoming json: {
#     "board_id": 23,
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "C0:EE:40:84:DD:56",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "58a99b0107e64cd40ea5e6607882cbe2",
#     "serial_port": "",
#     "timeout": 5
# }
# [2023-02-01 23:26:01.056] [board_logger] [trace] Board object created 23
# [2023-02-01 23:26:01.056] [board_logger] [debug] Use IP port 9000
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
def callback(*args):
    env.render()

model.learn(total_timesteps=2048, callback=callback, tb_log_name="runs")
# Out:
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.5
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.3333333333333333
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.25
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.16666666666666666
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.14285714285714285
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.125
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.1111111111111111
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.2727272727272727
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.25
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.23076923076923078
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.21428571428571427
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.1875
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.23529411764705882
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2222222222222222
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.21052631578947367
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.19047619047619047
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.22727272727272727
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.21739130434782608
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.20833333333333334
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.12
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.12
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# ...
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.6
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.48
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.28
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: right
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: right
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: left
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# -----------------------------
# | time/              |      |
# |    fps             | 9    |
# |    iterations      | 1    |
# |    time_elapsed    | 219  |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
model.save("ppo_kinetic.pth")

# %%
env.close()

# %%
env = KineticEnv()
# Out:
# [2023-02-01 23:29:59.814] [board_logger] [info] incoming json: {
#     "board_id": 23,
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "C0:EE:40:84:DD:56",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "58a99b0107e64cd40ea5e6607882cbe2",
#     "serial_port": "",
#     "timeout": 5
# }
# [2023-02-01 23:29:59.814] [board_logger] [trace] Board object created 23
# [2023-02-01 23:29:59.814] [board_logger] [debug] Use IP port 9000

# %%
model.load("ppo_kinetic.pth")

# %%
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render()
# Out:
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.64
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.68
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.72
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.76
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.8
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.84
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.84
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.84
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.88
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.92
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.96
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.96
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.92
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.88
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.84
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.8
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.76
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.72
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.68
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.64
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.12
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.08
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.04
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: right
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: left
# Predicted Direction: center
# Accuracy: 0.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.04
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.08
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.12
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.16
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.2
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.24
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.28
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.32
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.36
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.4
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.44
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.48
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.52
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.56
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.6
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.64
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.68
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.72
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.76
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.8
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.84
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.88
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.92
# Current Direction: center
# Predicted Direction: center
# Accuracy: 0.96
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
# Current Direction: center
# Predicted Direction: center
# Accuracy: 1.0
